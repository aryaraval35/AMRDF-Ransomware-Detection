# %%
# Cell 1 — Title and purpose
# ============================================================
# NOTEBOOK 01 — DATA LOADING
# Stage 3: Memory Feature Collection Layer
# Dataset: CIC-MalMem-2022 (Obfuscated-MalMem2022.csv)
# Purpose: Load dataset, inspect structure, understand columns
# ============================================================

# %%
# Cell 2 — Import libraries
import pandas as pd
import numpy as np
import os

print("Libraries loaded successfully")
# Out:
# Libraries loaded successfully

# %%
# Cell 3 — Define paths
BASE_DIR    = os.path.abspath(os.path.join(os.getcwd(), '..'))
RAW_PATH    = os.path.join(BASE_DIR, 'data', 'raw', 'Obfuscated-MalMem2022.csv')
PROC_DIR    = os.path.join(BASE_DIR, 'data', 'processed')

print("Base directory :", BASE_DIR)
print("Dataset path   :", RAW_PATH)
print("File exists    :", os.path.exists(RAW_PATH))
# Out:
# Base directory : c:\Users\aryar\OneDrive\Desktop\AMRDF\AMRDF_Ransomware_Detaction
# Dataset path   : c:\Users\aryar\OneDrive\Desktop\AMRDF\AMRDF_Ransomware_Detaction\data\raw\Obfuscated-MalMem2022.csv
# File exists    : True

# %%
# Cell 4 — Load the dataset
df = pd.read_csv(RAW_PATH)
print(f"Dataset shape  : {df.shape}")
print(f"Rows           : {df.shape[0]:,}")
print(f"Columns        : {df.shape[1]}")
# Out:
# Dataset shape  : (58596, 57)
# Rows           : 58,596
# Columns        : 57

# %%
# Cell 5 — First look at the data
df.head(5)
# Out:
#   Category  pslist.nproc  pslist.nppid  pslist.avg_threads  \
# 0   Benign            45            17           10.555556
# 1   Benign            47            19           11.531915
# 2   Benign            40            14           14.725000
# 3   Benign            32            13           13.500000
# 4   Benign            42            16           11.452381
#
#    pslist.nprocs64bit  pslist.avg_handlers  dlllist.ndlls  \
# 0                   0           202.844444           1694
# 1                   0           242.234043           2074
# 2                   0           288.225000           1932
# 3                   0           264.281250           1445
# 4                   0           281.333333           2067
#
#    dlllist.avg_dlls_per_proc  handles.nhandles  handles.avg_handles_per_proc  \
# 0                  38.500000              9129                    212.302326
# 1                  44.127660             11385                    242.234043
# ...

# %%
# Cell 6 — Column names
print("All columns in the dataset:\n")
for i, col in enumerate(df.columns, 1):
    print(f"  {i:02d}. {col}")
# Out:
# All columns in the dataset:
#
#   01. Category
#   02. pslist.nproc
#   03. pslist.nppid
#   04. pslist.avg_threads
#   05. pslist.nprocs64bit
#   06. pslist.avg_handlers
#   07. dlllist.ndlls
#   08. dlllist.avg_dlls_per_proc
#   09. handles.nhandles
#   10. handles.avg_handles_per_proc
#   11. handles.nport
#   12. handles.nfile
#   13. handles.nevent
#   14. handles.ndesktop
#   15. handles.nkey
#   16. handles.nthread
#   17. handles.ndirectory
#   18. handles.nsemaphore
#   19. handles.ntimer
#   20. handles.nsection
#   21. handles.nmutant
#   22. ldrmodules.not_in_load
#   23. ldrmodules.not_in_init
#   24. ldrmodules.not_in_mem
#   25. ldrmodules.not_in_load_avg
#   26. ldrmodules.not_in_init_avg
#   27. ldrmodules.not_in_mem_avg
#   28. malfind.ninjections
#   29. malfind.commitCharge
#   30. malfind.protection
#   31. malfind.uniqueInjections
#   32. psxview.not_in_pslist
#   33. psxview.not_in_eprocess_pool
#   34. psxview.not_in_ethread_pool
# ...

# %%
# Cell 7 — Data types of each column
print("Column data types:\n")
print(df.dtypes)
# Out:
# Column data types:
#
# Category                                   object
# pslist.nproc                                int64
# pslist.nppid                                int64
# pslist.avg_threads                        float64
# pslist.nprocs64bit                          int64
# pslist.avg_handlers                       float64
# dlllist.ndlls                               int64
# dlllist.avg_dlls_per_proc                 float64
# handles.nhandles                            int64
# handles.avg_handles_per_proc              float64
# handles.nport                               int64
# handles.nfile                               int64
# handles.nevent                              int64
# handles.ndesktop                            int64
# handles.nkey                                int64
# handles.nthread                             int64
# handles.ndirectory                          int64
# handles.nsemaphore                          int64
# ...

# %%
# Cell 8 — Check the label/target column
# CIC-MalMem-2022 uses 'Category' and 'Class' columns
print("Unique values in 'Category' column:")
print(df['Category'].value_counts())
print()
print("Unique values in 'Class' column:")
print(df['Class'].value_counts())
# Out:
# Unique values in 'Category' column:
# Category
# Benign                                                                                     29298
# Spyware-Gator-1bdcd3b777965f67678748d2577b119a275aca9aed9549d45e64e692a54a7b5e-1.raw           2
# Spyware-Gator-1bfb316482877ee42e5a5078fef44c0eb51bc44c1e88ecbccd02ce4dc4694bd3-2.raw           2
# Spyware-Gator-1bfb316482877ee42e5a5078fef44c0eb51bc44c1e88ecbccd02ce4dc4694bd3-10.raw          2
# Spyware-Gator-1bfb316482877ee42e5a5078fef44c0eb51bc44c1e88ecbccd02ce4dc4694bd3-1.raw           2
#                                                                                            ...
# Spyware-Gator-0b25829d15dc951a44e7652fc6de9d936d7d51f29586d56dbf8fccea419252ac-6.raw           1
# Spyware-Gator-0b25829d15dc951a44e7652fc6de9d936d7d51f29586d56dbf8fccea419252ac-5.raw           1
# Spyware-Gator-0b25829d15dc951a44e7652fc6de9d936d7d51f29586d56dbf8fccea419252ac-4.raw           1
# ...

# %%
# Cell 9 — Check missing values
missing = df.isnull().sum()
missing_pct = (missing / len(df)) * 100
missing_df = pd.DataFrame({
    'Missing Count': missing,
    'Missing Percent': missing_pct
}).sort_values('Missing Count', ascending=False)

print("Top 15 columns with missing values:\n")
print(missing_df[missing_df['Missing Count'] > 0].head(15))
print(f"\nTotal columns with missing values: {(missing > 0).sum()}")
# Out:
# Top 15 columns with missing values:
#
# Empty DataFrame
# Columns: [Missing Count, Missing Percent]
# Index: []
#
# Total columns with missing values: 0

# %%
# Cell 10 — Basic statistics
print("Basic statistics of numerical columns:")
df.describe().T
# Out:
# Basic statistics of numerical columns:
#                                           count          mean          std  \
# pslist.nproc                            58596.0     41.394771     5.777249
# pslist.nppid                            58596.0     14.713837     2.656748
# pslist.avg_threads                      58596.0     11.341655     1.588231
# pslist.nprocs64bit                      58596.0      0.000000     0.000000
# pslist.avg_handlers                     58596.0    247.509819   111.857790
# dlllist.ndlls                           58596.0   1810.805447   329.782639
# dlllist.avg_dlls_per_proc               58596.0     43.707806     5.742023
# handles.nhandles                        58596.0  10258.584221  4866.864130
# handles.avg_handles_per_proc            58596.0    249.560958   145.999866
# handles.nport                           58596.0      0.000000     0.000000
# handles.nfile                           58596.0    899.119513  3432.351200
# ...

# %%
# Cell 11 — Save a quick summary
summary = {
    'total_rows': df.shape[0],
    'total_columns': df.shape[1],
    'missing_values': df.isnull().sum().sum(),
    'classes': df['Class'].value_counts().to_dict(),
    'categories': df['Category'].value_counts().to_dict()
}

print("Dataset Summary:")
for key, val in summary.items():
    print(f"  {key}: {val}")

print("\nNotebook 01 complete. Proceed to 02_eda.ipynb")
# Out:
# Dataset Summary:
#   total_rows: 58596
#   total_columns: 57
#   missing_values: 0
#   classes: {'Benign': 29298, 'Malware': 29298}
# ...
